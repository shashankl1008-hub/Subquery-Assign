# %%
SUBQUERY Basic Level

# %% [markdown]
# Ans Q 1--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q2--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q3--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q 4--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q5--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***SUBQUERY Intermediate Level***

# %% [markdown]
# Ans Q1--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q 2--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q3--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q4--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q5---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SUBQUERY ADVANCED LEVEL**

# %% [markdown]
# Ans Q1--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q2--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans q3--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q 4--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q5--
#
# ![image.png](data:image/png;base64,...)
